# %% [markdown]
# ### Introduction to Pandas Bonus/Study Notebook

# %% [markdown]
# Topics to study for the test.  Some of these are already in this notebook, but I suggest you add the remaining ones.  See Lecture notebooks for examples.  (Panda Introduction and Pandas_merge_groupby_apply)

# %% [markdown]
# - Panda Series (enhanced one dimensional array)
#     - initialize with list or dictionary
#     - accessing values
#     - calculate descriptive statistics
#     - creating custom index
# - Panda DataFrames (enhanced two-dimensional array)
#     - initialize from CSV
#     - export to CSV
#     - customize index
#     - select columns and select rows (at the same time or independently)
#     - boolean (conditional) indexing/selection
#     - accessing a specific cell by row and column
#     - calculate descriptive statistics on the entire DataFrame or specific columns and rows
#     - calculate sum, mean, min, max based on columns or rows (don’t forget to set the axis for columns) for the entire DataFrame or specific columns or specific rows
#     - add a new column to a DataFrame based on a list
#     - groupby and sort_values
#     - unique values and counts for columns (value_counts)
#     - info, shape, head, tail
#     - add a new column to DataFrame based on existing columns
#     - dealing with null values (replacing values or dropping rows or columns with null values)

# %%
import os
import numpy as np
import pandas as pd
from pandas import Series, DataFrame

import sklearn.linear_model
import matplotlib as mpl
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
# Set the path to our data location
datapath = os.path.join(".", "")
datapath
# Out:
# './'

# %%
hogwarts_datafile = 'hogwarts_grades.csv'

# %%
grades = pd.read_csv(datapath + hogwarts_datafile, index_col='Name')

# %%
grades = pd.read_csv(datapath + hogwarts_datafile)
grades
# Out:
#         Name  Potions  Transfiguration  Runes  Defense  Divination  \
# 0      Harry     80.0             92.0    NaN    100.0        71.0
# 1   Hermione    100.0            100.0  100.0    100.0         NaN
# 2        Ron     70.0             83.0    NaN     92.0        73.0
# 3      Draco    100.0             88.0    NaN     72.0        75.0
# 4     Crabbe     31.0             15.0    NaN     29.0         6.0
# 5       Fred     75.0             93.0    NaN     91.0         NaN
# 6     George     75.0             93.0    NaN     91.0         NaN
# 7      Goyle     23.0             43.0    NaN     32.0        11.0
# 8       Luna     94.0             97.0  100.0     93.0        98.0
# 9        Cho      NaN             92.0    NaN     95.0        93.0
# 10    Cedric      NaN             98.0    NaN      NaN         NaN
# 11   Neville      NaN             84.0    NaN     71.0        78.0
#
#     Data Science  Charms  Herbology
# 0           92.0    93.0       83.0
# 1          100.0   100.0      100.0
# 2           98.0    95.0       87.0
# 3           72.0    92.0       92.0
# 4            3.0    70.0       52.0
# 5           58.0     NaN        NaN
# 6           58.0     NaN        NaN
# 7           21.0    41.0       49.0
# 8          100.0    98.0       98.0
# 9           98.0    95.0       97.0
# 10           NaN     NaN        NaN
# 11           NaN     NaN      100.0

# %%
grades.set_index('Name',inplace=True)

# %% [markdown]
# Get information the Dataframe

# %%
grades.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 12 entries, Harry to Neville
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Potions          9 non-null      float64
#  1   Transfiguration  12 non-null     float64
#  2   Runes            2 non-null      float64
#  3   Defense          11 non-null     float64
#  4   Divination       8 non-null      float64
#  5   Data Science     10 non-null     float64
#  6   Charms           8 non-null      float64
#  7   Herbology        9 non-null      float64
# dtypes: float64(8)
# memory usage: 864.0+ bytes

# %% [markdown]
# See the beginning of the DataFrame

# %%
grades.head(5)
# Out:
#           Potions  Transfiguration  Runes  Defense  Divination  Data Science  \
# Name
# Harry        80.0             92.0    NaN    100.0        71.0          92.0
# Hermione    100.0            100.0  100.0    100.0         NaN         100.0
# Ron          70.0             83.0    NaN     92.0        73.0          98.0
# Draco       100.0             88.0    NaN     72.0        75.0          72.0
# Crabbe       31.0             15.0    NaN     29.0         6.0           3.0
#
#           Charms  Herbology
# Name
# Harry       93.0       83.0
# Hermione   100.0      100.0
# Ron         95.0       87.0
# Draco       92.0       92.0
# Crabbe      70.0       52.0

# %% [markdown]
# See the end of the DataFrame

# %%
grades.tail(5)
# Out:
#          Potions  Transfiguration  Runes  Defense  Divination  Data Science  \
# Name
# Goyle       23.0             43.0    NaN     32.0        11.0          21.0
# Luna        94.0             97.0  100.0     93.0        98.0         100.0
# Cho          NaN             92.0    NaN     95.0        93.0          98.0
# Cedric       NaN             98.0    NaN      NaN         NaN           NaN
# Neville      NaN             84.0    NaN     71.0        78.0           NaN
#
#          Charms  Herbology
# Name
# Goyle      41.0       49.0
# Luna       98.0       98.0
# Cho        95.0       97.0
# Cedric      NaN        NaN
# Neville     NaN      100.0

# %% [markdown]
# See the shape of the DataFrame (rows and columns)

# %%
grades.shape
# Out:
# (12, 8)

# %% [markdown]
# Get the column names

# %%
grades.columns
# Out:
# Index(['Potions', 'Transfiguration', 'Runes', 'Defense', 'Divination',
#        'Data Science', 'Charms', 'Herbology'],
#       dtype='object')

# %% [markdown]
# Show a specific set of columns

# %%
grades[['Potions','Herbology']]
# Out:
#           Potions  Herbology
# Name
# Harry        80.0       83.0
# Hermione    100.0      100.0
# Ron          70.0       87.0
# Draco       100.0       92.0
# Crabbe       31.0       52.0
# Fred         75.0        NaN
# George       75.0        NaN
# Goyle        23.0       49.0
# Luna         94.0       98.0
# Cho           NaN       97.0
# Cedric        NaN        NaN
# Neville       NaN      100.0

# %% [markdown]
# Change all the null/NaN values to -1 in place.

# %%
grades.fillna(-1, inplace=True)

# %%
grades
# Out:
#           Potions  Transfiguration  Runes  Defense  Divination  Data Science  \
# Name
# Harry        80.0             92.0   -1.0    100.0        71.0          92.0
# Hermione    100.0            100.0  100.0    100.0        -1.0         100.0
# Ron          70.0             83.0   -1.0     92.0        73.0          98.0
# Draco       100.0             88.0   -1.0     72.0        75.0          72.0
# Crabbe       31.0             15.0   -1.0     29.0         6.0           3.0
# Fred         75.0             93.0   -1.0     91.0        -1.0          58.0
# George       75.0             93.0   -1.0     91.0        -1.0          58.0
# Goyle        23.0             43.0   -1.0     32.0        11.0          21.0
# Luna         94.0             97.0  100.0     93.0        98.0         100.0
# Cho          -1.0             92.0   -1.0     95.0        93.0          98.0
# Cedric       -1.0             98.0   -1.0     -1.0        -1.0          -1.0
# Neville      -1.0             84.0   -1.0     71.0        78.0          -1.0
#
#           Charms  Herbology
# Name
# Harry       93.0       83.0
# Hermione   100.0      100.0
# Ron         95.0       87.0
# Draco       92.0       92.0
# Crabbe      70.0       52.0
# Fred        -1.0       -1.0
# George      -1.0       -1.0
# Goyle       41.0       49.0
# Luna        98.0       98.0
# Cho         95.0       97.0
# Cedric      -1.0       -1.0
# Neville     -1.0      100.0

# %% [markdown]
# Change all -1 back to NaN.

# %%
#grades[grades == -1] = np.nan
# OR
grades.replace(-1,np.nan, inplace=True)

# %%
grades
# Out:
#           Potions  Transfiguration  Runes  Defense  Divination  Data Science  \
# Name
# Harry        80.0             92.0    NaN    100.0        71.0          92.0
# Hermione    100.0            100.0  100.0    100.0         NaN         100.0
# Ron          70.0             83.0    NaN     92.0        73.0          98.0
# Draco       100.0             88.0    NaN     72.0        75.0          72.0
# Crabbe       31.0             15.0    NaN     29.0         6.0           3.0
# Fred         75.0             93.0    NaN     91.0         NaN          58.0
# George       75.0             93.0    NaN     91.0         NaN          58.0
# Goyle        23.0             43.0    NaN     32.0        11.0          21.0
# Luna         94.0             97.0  100.0     93.0        98.0         100.0
# Cho           NaN             92.0    NaN     95.0        93.0          98.0
# Cedric        NaN             98.0    NaN      NaN         NaN           NaN
# Neville       NaN             84.0    NaN     71.0        78.0           NaN
#
#           Charms  Herbology
# Name
# Harry       93.0       83.0
# Hermione   100.0      100.0
# Ron         95.0       87.0
# Draco       92.0       92.0
# Crabbe      70.0       52.0
# Fred         NaN        NaN
# George       NaN        NaN
# Goyle       41.0       49.0
# Luna        98.0       98.0
# Cho         95.0       97.0
# Cedric       NaN        NaN
# Neville      NaN      100.0

# %% [markdown]
# Drop all rows that contain NaN

# %%
grades.dropna()
# Out:
#       Potions  Transfiguration  Runes  Defense  Divination  Data Science  \
# Name
# Luna     94.0             97.0  100.0     93.0        98.0         100.0
#
#       Charms  Herbology
# Name
# Luna    98.0       98.0

# %% [markdown]
# Drop all columns that contain NaN.

# %%
grades.dropna(axis='columns')
# Out:
#           Transfiguration
# Name
# Harry                92.0
# Hermione            100.0
# Ron                  83.0
# Draco                88.0
# Crabbe               15.0
# Fred                 93.0
# George               93.0
# Goyle                43.0
# Luna                 97.0
# Cho                  92.0
# Cedric               98.0
# Neville              84.0

# %% [markdown]
# Add a column named 'Total' that has the total sum of all points for each student.

# %%
grades['Total'] = grades.sum(axis='columns')
grades
# Out:
#           Potions  Transfiguration  Runes  Defense  Divination  Data Science  \
# Name
# Harry        80.0             92.0    NaN    100.0        71.0          92.0
# Hermione    100.0            100.0  100.0    100.0         NaN         100.0
# Ron          70.0             83.0    NaN     92.0        73.0          98.0
# Draco       100.0             88.0    NaN     72.0        75.0          72.0
# Crabbe       31.0             15.0    NaN     29.0         6.0           3.0
# Fred         75.0             93.0    NaN     91.0         NaN          58.0
# George       75.0             93.0    NaN     91.0         NaN          58.0
# Goyle        23.0             43.0    NaN     32.0        11.0          21.0
# Luna         94.0             97.0  100.0     93.0        98.0         100.0
# Cho           NaN             92.0    NaN     95.0        93.0          98.0
# Cedric        NaN             98.0    NaN      NaN         NaN           NaN
# Neville       NaN             84.0    NaN     71.0        78.0           NaN
#
#           Charms  Herbology  Total
# Name
# Harry       93.0       83.0  611.0
# Hermione   100.0      100.0  700.0
# Ron         95.0       87.0  598.0
# Draco       92.0       92.0  591.0
# Crabbe      70.0       52.0  206.0
# Fred         NaN        NaN  317.0
# George       NaN        NaN  317.0
# Goyle       41.0       49.0  220.0
# Luna        98.0       98.0  778.0
# Cho         95.0       97.0  570.0
# Cedric       NaN        NaN   98.0
# Neville      NaN      100.0  333.0

# %% [markdown]
# Drop the column 'Total' that was just added.

# %%
grades.drop('Total',axis='columns',inplace=True)

# %%
grades
# Out:
#           Potions  Transfiguration  Runes  Defense  Divination  Data Science  \
# Name
# Harry        80.0             92.0    NaN    100.0        71.0          92.0
# Hermione    100.0            100.0  100.0    100.0         NaN         100.0
# Ron          70.0             83.0    NaN     92.0        73.0          98.0
# Draco       100.0             88.0    NaN     72.0        75.0          72.0
# Crabbe       31.0             15.0    NaN     29.0         6.0           3.0
# Fred         75.0             93.0    NaN     91.0         NaN          58.0
# George       75.0             93.0    NaN     91.0         NaN          58.0
# Goyle        23.0             43.0    NaN     32.0        11.0          21.0
# Luna         94.0             97.0  100.0     93.0        98.0         100.0
# Cho           NaN             92.0    NaN     95.0        93.0          98.0
# Cedric        NaN             98.0    NaN      NaN         NaN           NaN
# Neville       NaN             84.0    NaN     71.0        78.0           NaN
#
#           Charms  Herbology
# Name
# Harry       93.0       83.0
# Hermione   100.0      100.0
# Ron         95.0       87.0
# Draco       92.0       92.0
# Crabbe      70.0       52.0
# Fred         NaN        NaN
# George       NaN        NaN
# Goyle       41.0       49.0
# Luna        98.0       98.0
# Cho         95.0       97.0
# Cedric       NaN        NaN
# Neville      NaN      100.0

# %% [markdown]
# Change Fred's grade in Potions to an 88.

# %%
grades.loc['Fred','Potions'] = 88

# %%
grades
# Out:
#           Potions  Transfiguration  Runes  Defense  Divination  Data Science  \
# Name
# Harry        80.0             92.0    NaN    100.0        71.0          92.0
# Hermione    100.0            100.0  100.0    100.0         NaN         100.0
# Ron          70.0             83.0    NaN     92.0        73.0          98.0
# Draco       100.0             88.0    NaN     72.0        75.0          72.0
# Crabbe       31.0             15.0    NaN     29.0         6.0           3.0
# Fred         88.0             93.0    NaN     91.0         NaN          58.0
# George       75.0             93.0    NaN     91.0         NaN          58.0
# Goyle        23.0             43.0    NaN     32.0        11.0          21.0
# Luna         94.0             97.0  100.0     93.0        98.0         100.0
# Cho           NaN             92.0    NaN     95.0        93.0          98.0
# Cedric        NaN             98.0    NaN      NaN         NaN           NaN
# Neville       NaN             84.0    NaN     71.0        78.0           NaN
#
#           Charms  Herbology
# Name
# Harry       93.0       83.0
# Hermione   100.0      100.0
# Ron         95.0       87.0
# Draco       92.0       92.0
# Crabbe      70.0       52.0
# Fred         NaN        NaN
# George       NaN        NaN
# Goyle       41.0       49.0
# Luna        98.0       98.0
# Cho         95.0       97.0
# Cedric       NaN        NaN
# Neville      NaN      100.0

# %% [markdown]
# Select rows based on condition.

# %%
grades.loc[(grades['Transfiguration'] < 60) & (grades['Charms'] < 70)]
# Out:
#        Potions  Transfiguration  Runes  Defense  Divination  Data Science  \
# Name
# Goyle     23.0             43.0    NaN     32.0        11.0          21.0
#
#        Charms  Herbology
# Name
# Goyle    41.0       49.0
